# %% [markdown]
# # Kiểu dữ liệu

# %%
print(type(10))
print(type(5.5))
print(type("Hello Python"))
print(type(True))
print(type(False))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
a = "Hello"
b = "Python"
c = a + b
print(c)
print(c * 3)
print(c + c + c)
# Out:
# HelloPython
# HelloPythonHelloPythonHelloPython
# HelloPythonHelloPythonHelloPython

# %%
# True -> 1, False -> 0
a = False
b = False
c = a + b
print(c)
# Out:
# 0

# %%
a = 10
b = True
c = a + b
print(c)
# Out:
# 11

# %%
a = "Hello"
b = 2
c = a + b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18412/2315631771.py in <module>
#       1 a = "Hello"
#       2 b = 2
# ----> 3 c = a + b
#       4 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Toán tử

# %% [markdown]
# ## Toán tử cộng

# %%
5 + 4
# Out:
# 9

# %%
5.5 + 4.5
# Out:
# 10.0

# %% [markdown]
# ## Toán tử trừ

# %%
10 - 5
# Out:
# 5

# %% [markdown]
# ## Toán tử nhân

# %%
2.5 * 3
# Out:
# 7.5

# %% [markdown]
# ## Toán tử chia

# %%
10 / 4
# Out:
# 2.5

# %% [markdown]
# ## Chia lấy dư

# %%
7 / 3
# Out:
# 2.3333333333333335

# %%
7 // 3
# Out:
# 2

# %%
7 % 3
# Out:
# 1

# %% [markdown]
# ## Lũy thừa

# %%
2 ** 4
# Out:
# 16

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y
# Out:
# True

# %%
x + y >= z
# Out:
# True

# %%
x ** 2 <= z
# Out:
# False

# %%
(x ** 2 - z) ** 0.5 == y
# Out:
# True

# %%
x + y + (x < y) - 1 <= z
# Out:
# True

# %%
x * y - z <= (z ** 2 + 40) ** 0.5
# Out:
# True

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 5
a = a + 1  # tăng giá trị của a lên 1 đơn vị
print(a)
# Out:
# 6

# %%
a = 5
a += 1
print(a)
# Out:
# 6

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y and z > x
# Out:
# True

# %%
x + y >= z and z ** 0.5 <= y
# Out:
# True

# %%
z - y > x and z - x > y
# Out:
# False

# %%
not(z - y > z or z - x > y)
# Out:
# True

# %%
not(z - y > x or z - x + 1 >= x)
# Out:
# False
