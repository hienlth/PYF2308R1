# %% [markdown]
# # Function

# %% [markdown]
# ## Function(hàm) là gì?

# %% [markdown]
# Hàm (function) là một khối lệnh đặc biệt, nó được đặt tên, giúp mã chương trình dễ đọc hơn, và có thể gọi để sử dụng ở các nơi khác nhau trong chương trình. Hàm chính là khối lệnh có thể tái sử dụng (reuseable).

# %% [markdown]
# ### Hàm
#
# Cú pháp:
#
# `def <tên hàm>(<tham số>):
#     //Nội dung hàm`
#
# Gọi hàm:
# `<tên hàm>(<giá trị đầu vào>)`

# %% [markdown]
# ### Ví dụ: Hàm in

# %%
# Viết hàm để giới thiệu về khóa học
def print_course_info():
    print("**********************************")
    print("* Course: Python Fundamental     *")
    print("* Lesson: 13                     *")
    print("* Organization: Codegym Online   *")
    print("**********************************")

# %%
print_course_info()
print_course_info()
print_course_info()
print_course_info()
print_course_info()
print_course_info()
# Out:
# **********************************
# * Course: Python Fundamental     *
# * Lesson: 13                     *
# * Organization: Codegym Online   *
# **********************************
# **********************************
# * Course: Python Fundamental     *
# * Lesson: 13                     *
# * Organization: Codegym Online   *
# **********************************
# **********************************
# * Course: Python Fundamental     *
# * Lesson: 13                     *
# * Organization: Codegym Online   *
# **********************************
# **********************************
# * Course: Python Fundamental     *
# * Lesson: 13                     *
# * Organization: Codegym Online   *
# **********************************
# **********************************
# * Course: Python Fundamental     *
# * Lesson: 13                     *
# * Organization: Codegym Online   *
# **********************************
# **********************************
# * Course: Python Fundamental     *
# * Lesson: 13                     *
# * Organization: Codegym Online   *
# **********************************

# %% [markdown]
# ### Ví dụ: Hàm tính giá trị tuyệt đối

# %%
# Viết hàm để in ra giá trị tuyệt đối của biến được input từ người dùng
def print_abs():
    number = int(input("Please input number: "))
    if number >= 0:
        print(f"Absolute value is {number}")
    else: 
        print(f"Absolute value is {-number}")

# %%
print_abs()
# Out:
# Please input number: 5
# Absolute value is 5

# %% [markdown]
# ### Ví dụ: Hàm vẽ hình tròn

# %% [markdown]
# ## Xây dựng và sử dụng hàm trong python

# %% [markdown]
# ### Hàm say_hello

# %%
# Viết hàm để in ra nội dung "Hello, my name is ...... I'm studying Python Fundamental"
def say_hello():
    print("Hello, my name is Long. I'm studying Python Fundamental")
    
say_hello()
# Out:
# Hello, my name is Long. I'm studying Python Fundamental

# %% [markdown]
# ### Hàm vẽ cây thông

# %% [markdown]
# ### Thực hành: Viết hàm vẽ ra hình ảnh như dưới đây:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## doc_string cho hàm

# %%
# Hàm tính chu vi hình chữ nhật
def calc_perimeter_rectangle():
    '''
    This function is used to calculate perimeter of rectangle.
    Input: length, width
    Output: perimeter (float)
    '''
    pass

print(len.__doc__)
# Out:
# Return the number of items in a container.

# %%
# Hàm xếp loại học sinh
# tính điểm trung bình 3 môn học Toán, Văn, Anh
# cho biết học lực là Giỏi (>= 6.5) | Khá (5 -> 6.5) | Trung Bình (< 5)
def classify_student():
    '''
    This function is used to classify student based on marks
    Input: math_score, literature_score, english_score
    Output: Student Rating
    '''
    pass

# %% [markdown]
# ## Phạm vi biến

# %%
# Hàm tính tổng các số từ 1 đến 10

def calc_sum():
    total = 0
    n = 5
    for i in range(n + 1):
        total += i
    print(total)
    
calc_sum()
print(n)
# Out:
# 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6020/3862139717.py in <module>
#       9
#      10 calc_sum()
# ---> 11 print(n)
#
# NameError: name 'n' is not defined

# %% [markdown]
# ## Đối số của hàm

# %%
# Hàm tính thể tích hình lập phương
def calc_cube_volume(side):
    print(f"Cube volume is {side ** 3}")
    
calc_cube_volume(5)
calc_cube_volume(10)
calc_cube_volume(15)
# Out:
# Cube volume is 125
# Cube volume is 1000
# Cube volume is 3375

# %%
# Hàm xếp loại học sinh
# tính điểm trung bình 3 môn học Toán, Văn, Anh
# cho biết học lực là Giỏi (>= 6.5) | Khá (5 -> 6.5) | Trung Bình (< 5)
def classify_student(math_score, literature_score, english_score):
    avg_score = (math_score + literature_score + english_score) / 3
    if avg_score >= 6.5:
        print("Grading: Excellent")
    elif avg_score >= 5:
        print("Grading: Good")
    else:
        print("Grading: Average")

# %%
classify_student(9, 9, 9)
# Out:
# Grading: Excellent

# %%
classify_student(6.5, 5, 6)
# Out:
# Grading: Good

# %% [markdown]
# ### Thực hành: Viết hàm nhận vào một số nguyên và kiểm tra xem số đó có phải là số nguyên tố hay không.

# %%
def is_prime_number(number):
    # assumption
    is_prime = True  # giả định n là số nguyên tố
    
    for i in range(2, number):
        if number % i == 0:
            print(f"{number} is not a prime number")
            is_prime = False
            break
            
    if is_prime:
        print(f"{number} is a prime number")
            
is_prime_number(47)
# Out:
# 47 is a prime number

# %% [markdown]
# ## Đối số có giá trị mặc định

# %%
print("Hello World.", "Hello World")
print("Hello World")
# Out:
# Hello World. Hello World
# Hello World

# %%
def intro(name, course="Python Fundamental"):
    print(f"My name is {name}")
    print(f"My course is {course}")
    
intro("Long", "Javascript")
# Out:
# My name is Long
# My course is Javascript

# %% [markdown]
# ## Giá trị trả về của hàm

# %% [markdown]
# # return
#
# Cú pháp:
#
# `return <giá trị trả về>`
#
# ##### Lưu ý: Sau khi thực hiện lệnh return, chương trình sẽ thoát khỏi hàm ngay lập tức (những lệnh sau đó không được thực hiện)
#
# Ví dụ:
#
# Hãy viết 1 hàm trả về giá trị trung bình của 2 số bất kỳ

# %%
def calc_average(num1, num2):
    return (num1 + num2) / 2
    
result = calc_average(4, 5)

print(result)
# Out:
# 4.5

# %%
# Hàm tính chiều dài của chuỗi
# Viết hàm nhận vào một chuỗi và trả về chiều dài của chuỗi
def calc_length(string):
    return len(string)

print(calc_length("PYF2304R1"))
# Out:
# 9

# %%
# Hàm tính giai thừa
# Viết hàm nhận vào một số nguyên và trả về giai thừa của số nguyên đó
def calc_factorial(number):
    factorial = 1
    for i in range(2, number + 1):
        factorial *= i
    return factorial
print(calc_factorial(5))
# Out:
# 120

# %%
# Hàm kiểm tra năm nhuận
# Viết hàm nhận vào một số năm và trả về True nếu năm đó là năm nhuận, ngược lại trả về False
def is_leap_year(year):
    if (year % 400 == 0) or ((year % 4 == 0) and (year % 100 != 0)):
        return True
    else:
        return False
