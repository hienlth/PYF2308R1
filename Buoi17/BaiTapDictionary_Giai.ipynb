# %%
"""
Warm-up 1: Cho một danh sách sản phẩm như sau:
products = {
    'SMART WATCH': 550,
    'PHONE': 1000,
    'PLAYSTATION': 500,
    'LAPTOP': 1550,
    'MUSIC PLAYER': 600,
    'TABLET': 400 
}
Viết chương trình hiển thị các sản phẩm có giá bé hơn hoặc bằng so với giá tiền mà người dùng nhập
"""
expected_price = int(input("Please input expected price: "))

products = {
    'SMART WATCH': 550,
    'PHONE' : 1000,
    'PLAYSTATION': 500,
    'LAPTOP' : 1550,
    'MUSIC PLAYER' : 600,
    'TABLET' : 400 
}

for product, price in products.items():
    if price <= expected_price:
        print(product)
# Out:
# Please input expected price: 1000
# SMART WATCH
# PHONE
# PLAYSTATION
# MUSIC PLAYER
# TABLET

# %%
"""
Warm-up 2: 
"""

# %% [markdown]
# ## Bài 1: list to dict
# Cho 2 list có cùng số phần tử với nhau. Hãy tạo ra một dict từ 2 list đã cho theo format dưới đây:

# %% [markdown]
# **Input**

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]

# %% [markdown]
# **Output**

# %%
{'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %% [markdown]
# **Your code**

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
# code below this line
result = {}
for i in range(len(keys)):
    result[keys[i]] = values[i]

print(result)
# code above this line
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %% [markdown]
# ## Bài 2: merge dictionary
# Hãy gộp 2 dictionary sau đây thành một.

# %% [markdown]
# **Input**

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# **Output**

# %%
{'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# **Your code**

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}
# code below this line
dict1.update(dict2)
print(dict1)
# code above this line
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# ## Bài 3: where is the value?
# Hãy in ra giá trị của "history" trong dictionary dưới đây.

# %% [markdown]
# **Input**

# %%
sampleDict = { 
   "class":{ 
      "student":{ 
         "name":"Mike",
         "marks":{ 
            "physics":70,
            "history":80
         }
      }
   }
}

# %% [markdown]
# **Output**

# %%
80

# %% [markdown]
# **Your code**

# %%
sampleDict = { 
   "class":{ 
      "student":{ 
         "name":"Mike",
         "marks":{ 
            "physics":70,
            "history":80
         }
      }
   }
}
# code below this line
print(sampleDict["class"]["student"]["marks"]["history"])
# code above this line
# Out:
# 80

# %% [markdown]
# ## Bài 4: Delete set of keys from a dictionary
# Hãy xóa các key có trong set dưới đây ra khỏi dictionary.

# %% [markdown]
# **Input**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
  
}
keysToRemove = {"name", "salary"}

# %% [markdown]
# **Output:**

# %%
{'city': 'New york', 'age': 25}

# %% [markdown]
# **Your code**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
  
}
keysToRemove = {"name", "salary"}
# code below this line
for key in keysToRemove:
    del sampleDict[key]
    
print(sampleDict)
# code above this line
# Out:
# {'age': 25, 'city': 'New york'}

# %% [markdown]
# ## Bài 5: Check if a value 200 exists in a dictionary
# Hãy kiểm tra xem số 200 có phải là value của dictionary dưới đây không nhé.

# %% [markdown]
# **Input**

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300}

# %% [markdown]
# **Output**

# %%
True

# %% [markdown]
# **Your code**

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300}
# code below this line
print(200 in sampleDict.values())
# code above this line
# Out:
# True

# %% [markdown]
# ## Bài 6: rename key
# Hãy thay thế key `city` thành `location` trong dictionary dưới đây.

# %% [markdown]
# **Input**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}

# %% [markdown]
# **Output**

# %%
{
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "location": "New york"
}

# %% [markdown]
# **Your code**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}
# code below this line
sampleDict["location"] = sampleDict["city"]
del sampleDict["city"]
print(sampleDict)
# code above this line
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# ## Bài 7: key of minimum value
# Hãy in ra key chứa value nhỏ nhất trong dictionary dưới đây.

# %% [markdown]
# **Input**

# %%
sampleDict = {
  'Physics': 82,
  'Math': 65,
  'history': 75,
  'Science': 65
}

# %% [markdown]
# **Output**

# %% [raw]
# Math
# Science

# %% [markdown]
# **Your code**

# %%
sampleDict = {
  'Physics': 82,
  'Math': 65,
  'history': 75,
  'Science': 65
}
# code below this line

# 1. Find min score
min_mark = min(sampleDict.values())
print(min_mark)

# 2. Find subject with min_score
# for key, value in sampleDict.items():
#     if value == min_mark:
#         print(key)

for key in sampleDict.keys():
    if sampleDict[key] == min_mark:
        print(key)
# code above this line
# Out:
# 65
# Math
# Science

# %% [markdown]
# ## Bài 8: new salary
# Hãy tăng lương(`salary`) cho Brad từ 6500 lên 8500 trong dictionary dưới đây nhé.

# %% [markdown]
# **Input**

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 6500}
}

# %% [markdown]
# **Output**

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 8500}
}

# %% [markdown]
# **Your code**

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 6500}
}
# code below this line
# sampleDict['emp3']['salary'] = 8500
for key, value in sampleDict.items():
    if value['name'] == 'Brad':
        sampleDict[key]['salary'] = 8500

print(sampleDict)
# code above this line
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [raw]
# # Bài 9: Tính điểm chuẩn của một ngành
# Cho điểm thi của một ngành thuộc một trường đại học như sau:
#
# marks = [
#  20, 21, 20, 21, 22, 23, 20,
#  17, 16, 15, 20, 21, 23, 21,
#  20, 21, 24, 27, 20, 28, 26,
#  25, 24, 23, 23, 20, 21, 24,
#  22, 14, 13,15 1
# 5```
#
# Số lượng sinh viên cần lấy là: qty  10
#
#
# Hãy xác định điểm chuẩn sao cho tỉ lệ lấy không được vượt quá tối đa = 10

# %%
marks = [
 20, 21, 20, 21, 22, 23, 20,
 17, 16, 15, 20, 21, 23, 21,
 20, 21, 24, 27, 20, 28, 26,
 25, 24, 23, 23, 23, 21, 24,
 22, 14, 13, 12, 15
]
marks.sort(reverse=True)
print(marks)
statictics = {}
for item in marks:
    statictics[item] = marks.count(item)

print(statictics)
# Out:
# [28, 27, 26, 25, 24, 24, 24, 23, 23, 23, 23, 23, 22, 22, 21, 21, 21, 21, 21, 21, 20, 20, 20, 20, 20, 20, 17, 16, 15, 15, 14, 13, 12]
# {28: 1, 27: 1, 26: 1, 25: 1, 24: 3, 23: 5, 22: 2, 21: 6, 20: 6, 17: 1, 16: 1, 15: 2, 14: 1, 13: 1, 12: 1}
